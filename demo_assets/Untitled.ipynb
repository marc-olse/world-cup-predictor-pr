# %%
import requests
import json

uri = 'https://api.football-data.org/v4/competitions/WC/matches?season=2026&status=LIVE'
headers = { 'X-Auth-Token': '8db047fa8c8b4b7da95ba6773e8ca9f7' }

response = requests.get(uri, headers=headers)
for match in response.json()['matches']:
  print(match)
# Out:
# {'area': {'id': 2267, 'name': 'World', 'code': 'INT', 'flag': None}, 'competition': {'id': 2000, 'name': 'FIFA World Cup', 'code': 'WC', 'type': 'CUP', 'emblem': 'https://crests.football-data.org/wm26.png'}, 'season': {'id': 2398, 'startDate': '2026-06-11', 'endDate': '2026-07-19', 'currentMatchday': 1, 'winner': None}, 'id': 537392, 'utcDate': '2026-06-16T22:00:00Z', 'status': 'IN_PLAY', 'matchday': 1, 'stage': 'GROUP_STAGE', 'group': 'GROUP_I', 'lastUpdated': '2026-06-16T22:21:46Z', 'homeTeam': {'id': 8062, 'name': 'Iraq', 'shortName': 'Iraq', 'tla': 'IRQ', 'crest': 'https://crests.football-data.org/iraq.svg'}, 'awayTeam': {'id': 8872, 'name': 'Norway', 'shortName': 'Norway', 'tla': 'NOR', 'crest': 'https://crests.football-data.org/813.svg'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 0}, 'halfTime': {'home': None, 'away': None}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 276648, 'name': 'Pi
# ...

# %%
response.json()['matches'][0]
# Out:
# {'area': {'id': 2267, 'name': 'World', 'code': 'INT', 'flag': None},
#  'competition': {'id': 2000,
#   'name': 'FIFA World Cup',
#   'code': 'WC',
#   'type': 'CUP',
#   'emblem': 'https://crests.football-data.org/wm26.png'},
#  'season': {'id': 2398,
#   'startDate': '2026-06-11',
#   'endDate': '2026-07-19',
#   'currentMatchday': 1,
#   'winner': None},
#  'id': 537392,
#  'utcDate': '2026-06-16T22:00:00Z',
#  'status': 'IN_PLAY',
#  'matchday': 1,
#  'stage': 'GROUP_STAGE',
#  'group': 'GROUP_I',
#  'lastUpdated': '2026-06-16T22:21:46Z',
#  'homeTeam': {'id': 8062,
#   'name': 'Iraq',
#   'shortName': 'Iraq',
#   'tla': 'IRQ',
#   'crest': 'https://crests.football-data.org/iraq.svg'},
#  'awayTeam': {'id': 8872,
#   'name': 'Norway',
#   'shortName': 'Norway',
#   'tla': 'NOR',
#   'crest': 'https://crests.football-data.org/813.svg'},
#  'score': {'winner': 'DRAW',
#   'duration': 'REGULAR',
#   'fullTime': {'home': 0, 'away': 0},
#   'halfTime': {'home': None, 'away': None}},
# ...
